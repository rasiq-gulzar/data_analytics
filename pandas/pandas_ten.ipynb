# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\RASIK AHMAD DAR\\Downloads\\world_population.csv')

# %%
df.shape
# Out:
# (234, 17)

# %%
df.head(10)
# Out:
#    Rank CCA3    Country/Territory           Capital      Continent  \
# 0    36  AFG          Afghanistan             Kabul           Asia
# 1   138  ALB              Albania            Tirana         Europe
# 2    34  DZA              Algeria           Algiers         Africa
# 3   213  ASM       American Samoa         Pago Pago        Oceania
# 4   203  AND              Andorra  Andorra la Vella         Europe
# 5    42  AGO               Angola            Luanda         Africa
# 6   224  AIA             Anguilla        The Valley  North America
# 7   201  ATG  Antigua and Barbuda      Saint John’s  North America
# 8    33  ARG            Argentina      Buenos Aires  South America
# 9   140  ARM              Armenia           Yerevan           Asia
#
#    2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771         38972230         33753499         28189672
# 1          2842321          2866849          2882481          2913399
# ...

# %%
#now my aim is to make the country/territory and the continent as double indexing
df.set_index('Rank',inplace=True)
df.sort_index(inplace=True)

# %%
df.iloc[10:20]
# Out:
#      CCA3 Country/Territory      Capital Continent  2022 Population  \
# Rank
# 11    JPN             Japan        Tokyo      Asia        123951692
# 12    ETH          Ethiopia  Addis Ababa    Africa        123379924
# 13    PHL       Philippines       Manila      Asia        115559009
# 14    EGY             Egypt        Cairo    Africa        110990103
# 15    COD          DR Congo     Kinshasa    Africa         99010212
# 16    VNM           Vietnam        Hanoi      Asia         98186856
# 17    IRN              Iran       Tehran      Asia         88550570
# 18    TUR            Turkey       Ankara      Asia         85341241
# 19    DEU           Germany       Berlin    Europe         83369843
# 20    THA          Thailand      Bangkok      Asia         71697030
#
#       2020 Population  2015 Population  2010 Population  2000 Population  \
# Rank
# 11          125244761        127250933        128105431        126803861
# ...

# %%
df.loc[5]
# Out:
# CCA3                                 PAK
# Country/Territory               Pakistan
# Capital                        Islamabad
# Continent                           Asia
# 2022 Population                235824862
# 2020 Population                227196741
# 2015 Population                210969298
# 2010 Population                194454498
# 2000 Population                154369924
# 1990 Population                115414069
# 1980 Population                 80624057
# 1970 Population                 59290872
# Area (km²)                        881912
# Density (per km²)               267.4018
# Growth Rate                       1.0191
# World Population Percentage         2.96
# Name: 5, dtype: object

# %%
df.tail()
# Out:
#      CCA3       Capital  2022 Population  2020 Population  2015 Population  \
# Rank
# 230   MSR        Brades             4390             4500             5059
# 231   FLK       Stanley             3780             3747             3408
# 232   NIU         Alofi             1934             1942             1847
# 233   TKL      Nukunonu             1871             1827             1454
# 234   VAT  Vatican City              510              520              564
#
#       2010 Population  2000 Population  1990 Population  1980 Population  \
# Rank
# 230              4938             5138            10805            11452
# 231              3187             3080             2332             2240
# 232              1812             2074             2533             3637
# 233              1367             1666             1669             1647
# 234               596              651              700              733
#
# ...

# %%
#now using isin() method to filter the data

df[df['Capital'].isin(['Kabul', 'Tirana'])]
# Out:
#                              Rank CCA3 Capital  2022 Population  \
# Continent Country/Territory
# Asia      Afghanistan          36  AFG   Kabul         41128771
# Europe    Albania             138  ALB  Tirana          2842321
#
#                              2020 Population  2015 Population  \
# Continent Country/Territory
# Asia      Afghanistan               38972230         33753499
# Europe    Albania                    2866849          2882481
#
#                              2010 Population  2000 Population  \
# Continent Country/Territory
# Asia      Afghanistan               28189672         19542982
# Europe    Albania                    2913399          3182021
#
#                              1990 Population  1980 Population  \
# Continent Country/Territory
# Asia      Afghanistan               10694796         12486631
# Europe    Albania                    3295066          2941651
#
#                              1970 Population  Area (km²)  Density (per km²)  \
# ...

# %%
df['2022 Population'].mean()
# Out:
# np.float64(34074414.70940171)

# %%
df['Growth Rate'].nunique()
# Out:
# 180

# %%
df[df['Growth Rate'] > 10]
# Out:
# Empty DataFrame
# Columns: [Rank, CCA3, Capital, 2022 Population, 2020 Population, 2015 Population, 2010 Population, 2000 Population, 1990 Population, 1980 Population, 1970 Population, Area (km²), Density (per km²), Growth Rate, World Population Percentage]
# Index: []

# %%
#give me the example of this 
df2=df[(df['Area (km²)'] < 10000) & (df['Density (per km²)'] =='')]

# %%
#now i m going to use the isnull() method to filter the data
df[df['Capital'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Rank, CCA3, Capital, 2022 Population, 2020 Population, 2015 Population, 2010 Population, 2000 Population, 1990 Population, 1980 Population, 1970 Population, Area (km²), Density (per km²), Growth Rate, World Population Percentage]
# Index: []

# %%
#dropna() method to drop the missing values
df.dropna(subset=['Capital'],inplace=True)

# %%
df
# Out:
#                                  Rank CCA3      Capital  2022 Population  \
# Continent     Country/Territory
# Africa        Algeria              34  DZA      Algiers         44903225
#               Angola               42  AGO       Luanda         35588987
#               Benin                77  BEN   Porto-Novo         13352864
#               Botswana            144  BWA     Gaborone          2630296
#               Burkina Faso         58  BFA  Ouagadougou         22673762
# ...                               ...  ...          ...              ...
# South America Paraguay            109  PRY     Asunción          6780744
#               Peru                 44  PER         Lima         34049588
#               Suriname            170  SUR   Paramaribo           618040
#               Uruguay             133  URY   Montevideo          3422794
#               Venezuela            51  VEN      Caracas         28301696
#
# ...

# %%
#df.interpolate() now using this  what this function does is  is 
df.interpolate()
# Out:
# C:\Users\RASIK AHMAD DAR\AppData\Local\Temp\ipykernel_21952\717877254.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#                                  Rank CCA3      Capital  2022 Population  \
# Continent     Country/Territory
# Africa        Algeria              34  DZA      Algiers         44903225
#               Angola               42  AGO       Luanda         35588987
#               Benin                77  BEN   Porto-Novo         13352864
#               Botswana            144  BWA     Gaborone          2630296
#               Burkina Faso         58  BFA  Ouagadougou         22673762
# ...                               ...  ...          ...              ...
# South America Paraguay            109  PRY     Asunción          6780744
#               Peru                 44  PER         Lima         34049588
# ...

# %%
world_pop=df['World Population Percentage']
world_pop
# Out:
# Continent      Country/Territory
# Africa         Algeria              0.56
#                Angola               0.45
#                Benin                0.17
#                Botswana             0.03
#                Burkina Faso         0.28
#                                     ...
# South America  Paraguay             0.09
#                Peru                 0.43
#                Suriname             0.01
#                Uruguay              0.04
#                Venezuela            0.35
# Name: World Population Percentage, Length: 234, dtype: float64

# %%
#pd.pivot_table(df, values='value_column',
#index='index_column', columns='column_to_pivot')
#waht this function does is it creates a pivot table from the data frame like the one we have in excel 
#the values are the values we want to see in the pivot table 
df2=pd.pivot_table(df, values='2015 Population',index='Continent', columns='World Population Percentage')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, Africa to South America
# Data columns (total 70 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0.0     5 non-null      float64
#  1   0.01    6 non-null      float64
#  2   0.02    4 non-null      float64
#  3   0.03    3 non-null      float64
#  4   0.04    4 non-null      float64
#  5   0.05    3 non-null      float64
#  6   0.06    4 non-null      float64
#  7   0.07    4 non-null      float64
#  8   0.08    2 non-null      float64
#  9   0.09    5 non-null      float64
#  10  0.11    3 non-null      float64
#  11  0.12    2 non-null      float64
#  12  0.13    4 non-null      float64
#  13  0.14    3 non-null      float64
#  14  0.15    4 non-null      float64
#  15  0.16    1 non-null      float64
#  16  0.17    1 non-null      float64
#  17  0.2     1 non-null      float64
#  18  0.21    1 non-null      float64
#  19  0.22    3 non-null      float64
# ...

# %%
df2.to_excel('C:\\Users\\RASIK AHMAD DAR\\Downloads\\world_population_pivot_table.xlsx')

# %%
#df['date_column'] = pd.to_datetime(df['date_column']) withe a simepl example
data_date={'date':['2021-01-01','2021-01-02','2021-01-03']}
df_date=pd.DataFrame(data_date)
df_date['date']=pd.to_datetime(df_date['date'])
df_date
# Out:
#         date
# 0 2021-01-01
# 1 2021-01-02
# 2 2021-01-03
