# %%
import pandas as pd
#toady is about the data cleaning which means to clean the data and make it ready for the analysis

# %%
df2=pd.read_excel('dabc.xlsx')

# %%
df2.head(40)
# Out:
#     Customer Id                                               Name  Gender  \
# 0             1                         ###Braund, Mr. Owen Harris    male
# 1             2  %%Cumings, Mrs. John Bradley (Florence Briggs ...  female
# 2             3                            <Heikkinen, Miss. Laina  female
# 3             4     Futrelle, Mrs. Jacques Heath (Lily May Peel)..   women
# 4             5                           Allen, Mr. William Henry     man
# 5             6                                   Moran, Mr. James    male
# 6             7                            McCarthy, Mr. Timothy J    male
# 7             8                     Palsson, Master. Gosta Leonard    male
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
# ...

# %%
 # Standardize boolean columns
df['alone'] = df['alone'].replace({0.0: False, 1.0: True})
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 2
#       1 # Standardize boolean columns
# ----> 2 df['alone'] = df['alone'].replace({0.0: False, 1.0: True})
#       3 df.head()
#
# NameError: name 'df' is not defined

# %%
df['Do_Not_Contact'] = df['Do_Not_Contact'].replace({'N': 'No', 'Y': 'Yes'})
df.head(40)
# Out:
#     Customer Id                                               Name  Gender  \
# 0             1                         ###Braund, Mr. Owen Harris    male
# 1             2  %%Cumings, Mrs. John Bradley (Florence Briggs ...  female
# 2             3                            <Heikkinen, Miss. Laina  female
# 3             4     Futrelle, Mrs. Jacques Heath (Lily May Peel)..   women
# 4             5                           Allen, Mr. William Henry     man
# 5             6                                   Moran, Mr. James    male
# 6             7                            McCarthy, Mr. Timothy J    male
# 7             8                     Palsson, Master. Gosta Leonard    male
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
# ...

# %%
df['alive'] = df['alive'].replace({'no': 'No', 'yes': 'Yes'})
df.head(40)
# Out:
#     Customer Id                                               Name  Gender  \
# 0             1                         ###Braund, Mr. Owen Harris    male
# 1             2  %%Cumings, Mrs. John Bradley (Florence Briggs ...  female
# 2             3                            <Heikkinen, Miss. Laina  female
# 3             4     Futrelle, Mrs. Jacques Heath (Lily May Peel)..   women
# 4             5                           Allen, Mr. William Henry     man
# 5             6                                   Moran, Mr. James    male
# 6             7                            McCarthy, Mr. Timothy J    male
# 7             8                     Palsson, Master. Gosta Leonard    male
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
# ...

# %%
df['Phone_Number']=df['Phone_Number'].str.strip().str.replace('|',' ')
df['Phone_Number']=df['Phone_Number'].str.strip().str.replace('/',' ')
df['Phone_Number']=df['Phone_Number'].str.strip().str.replace('-',' ')
#or we can use regex to make it in a single line
# df['Phone_Number']=df['Phone_Number'].str.replace('[^a-zA-Z0-9]','',regex=True)


df.head(40)
# Out:
#     Customer Id                                               Name  Gender  \
# 0             1                         ###Braund, Mr. Owen Harris    male
# 1             2  %%Cumings, Mrs. John Bradley (Florence Briggs ...  female
# 2             3                            <Heikkinen, Miss. Laina  female
# 3             4     Futrelle, Mrs. Jacques Heath (Lily May Peel)..   women
# 4             5                           Allen, Mr. William Henry     man
# 5             6                                   Moran, Mr. James    male
# 6             7                            McCarthy, Mr. Timothy J    male
# 7             8                     Palsson, Master. Gosta Leonard    male
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
# ...

# %%
df['Name']=df['Name'].str.replace(')','')
df
# Out:
#     Customer Id                                               Name  Gender  \
# 0             1                         ###Braund, Mr. Owen Harris    male
# 1             2  %%Cumings, Mrs. John Bradley (Florence Briggs ...  female
# 2             3                            <Heikkinen, Miss. Laina  female
# 3             4      Futrelle, Mrs. Jacques Heath (Lily May Peel..   women
# 4             5                           Allen, Mr. William Henry     man
# 5             6                                   Moran, Mr. James    male
# 6             7                            McCarthy, Mr. Timothy J    male
# 7             8                     Palsson, Master. Gosta Leonard    male
# 8             9   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg  female
# 9            10                 Nasser, Mrs. Nicholas (Adele Achem  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
# ...

# %%
df['Gender']=df['Gender'].str.capitalize()
df['Gender']=df['Gender'].str.replace('Man','Male')
df['Gender']=df['Gender'].str.replace('Women','Female')
df
# Out:
#     Customer Id                                               Name  Gender  \
# 0             1                         ###Braund, Mr. Owen Harris    Male
# 1             2  %%Cumings, Mrs. John Bradley (Florence Briggs ...  Female
# 2             3                            <Heikkinen, Miss. Laina  Female
# 3             4      Futrelle, Mrs. Jacques Heath (Lily May Peel..  Female
# 4             5                           Allen, Mr. William Henry    Male
# 5             6                                   Moran, Mr. James    Male
# 6             7                            McCarthy, Mr. Timothy J    Male
# 7             8                     Palsson, Master. Gosta Leonard    Male
# 8             9   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg  Female
# 9            10                 Nasser, Mrs. Nicholas (Adele Achem  Female
# 10           11                    Sandstrom, Miss. Marguerite Rut  Female
# ...

# %%
df.shape
# Out:
# (32, 11)

# %%
df['Name']=df['Name'].str.lstrip('% # < >')
df
# Out:
#     Customer Id                                               Name  Gender  \
# 0             1                            Braund, Mr. Owen Harris    Male
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...  Female
# 2             3                             Heikkinen, Miss. Laina  Female
# 3             4      Futrelle, Mrs. Jacques Heath (Lily May Peel..  Female
# 4             5                           Allen, Mr. William Henry    Male
# 5             6                                   Moran, Mr. James    Male
# 6             7                            McCarthy, Mr. Timothy J    Male
# 7             8                     Palsson, Master. Gosta Leonard    Male
# 8             9   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg  Female
# 9            10                 Nasser, Mrs. Nicholas (Adele Achem  Female
# 10           11                    Sandstrom, Miss. Marguerite Rut  Female
# ...

# %%
df['Name']=df['Name'].str.replace('"','')


df
# Out:
#     Customer Id                                               Name  Gender  \
# 0             1                            Braund, Mr. Owen Harris    Male
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...  Female
# 2             3                             Heikkinen, Miss. Laina  Female
# 3             4      Futrelle, Mrs. Jacques Heath (Lily May Peel..  Female
# 4             5                           Allen, Mr. William Henry    Male
# 5             6                                   Moran, Mr. James    Male
# 6             7                            McCarthy, Mr. Timothy J    Male
# 7             8                     Palsson, Master. Gosta Leonard    Male
# 8             9   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg  Female
# 9            10                 Nasser, Mrs. Nicholas (Adele Achem  Female
# 10           11                    Sandstrom, Miss. Marguerite Rut  Female
# ...

# %%
df=df.drop_duplicates()
df.head(2)
# Out:
#    Customer Id                                               Name  Gender  \
# 0            1                            Braund, Mr. Owen Harris    Male
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  Female
#
#     Age                Address  Phone_Number Do_Not_Contact  SibSp  \
# 0  22.0  123 Shire Lane, Shire  123 545 5421             No      1
# 1  38.0    93 West Main Street  123 643 9775            Yes      1
#
#    embark_town alive  alone
# 0  Southampton    No  False
# 1    Cherbourg   Yes  False

# %%
df.head(10)
# Out:
#    Customer Id                                               Name  Gender  \
# 0            1                            Braund, Mr. Owen Harris    Male
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  Female
# 2            3                             Heikkinen, Miss. Laina  Female
# 3            4      Futrelle, Mrs. Jacques Heath (Lily May Peel..  Female
# 4            5                           Allen, Mr. William Henry    Male
# 5            6                                   Moran, Mr. James    Male
# 6            7                            McCarthy, Mr. Timothy J    Male
# 7            8                     Palsson, Master. Gosta Leonard    Male
# 8            9   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg  Female
# 9           10                 Nasser, Mrs. Nicholas (Adele Achem  Female
#
#     Age                                Address  Phone_Number Do_Not_Contact  \
# 0  22.0                  123 Shire Lane, Shire  123 545 5421             No
# ...

# %%
df=df.fillna('NDF')

# %%
df
# Out:
#     Customer Id                                               Name  Gender  \
# 0             1                            Braund, Mr. Owen Harris    Male
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...  Female
# 2             3                             Heikkinen, Miss. Laina  Female
# 3             4      Futrelle, Mrs. Jacques Heath (Lily May Peel..  Female
# 4             5                           Allen, Mr. William Henry    Male
# 5             6                                   Moran, Mr. James    Male
# 6             7                            McCarthy, Mr. Timothy J    Male
# 7             8                     Palsson, Master. Gosta Leonard    Male
# 8             9   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg  Female
# 9            10                 Nasser, Mrs. Nicholas (Adele Achem  Female
# 10           11                    Sandstrom, Miss. Marguerite Rut  Female
# ...

# %%
df.drop(columns='alone',inplace=True)
df
# Out:
#     Customer Id                                               Name  Gender  \
# 0             1                            Braund, Mr. Owen Harris    Male
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...  Female
# 2             3                             Heikkinen, Miss. Laina  Female
# 3             4      Futrelle, Mrs. Jacques Heath (Lily May Peel..  Female
# 4             5                           Allen, Mr. William Henry    Male
# 5             6                                   Moran, Mr. James    Male
# 6             7                            McCarthy, Mr. Timothy J    Male
# 7             8                     Palsson, Master. Gosta Leonard    Male
# 8             9   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg  Female
# 9            10                 Nasser, Mrs. Nicholas (Adele Achem  Female
# 10           11                    Sandstrom, Miss. Marguerite Rut  Female
# ...

# %%
df=df.drop_duplicates()
df.shape
# Out:
# (29, 10)

# %%
df['Name']=df['Name'].str.replace('(','')
df['Name']=df['Name'].str.replace(')','')
# Out:
# C:\Users\RASIK AHMAD DAR\AppData\Local\Temp\ipykernel_9512\2425626949.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name']=df['Name'].str.replace('(','')
# C:\Users\RASIK AHMAD DAR\AppData\Local\Temp\ipykernel_9512\2425626949.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name']=df['Name'].str.replace(')','')

# %%
df
# Out:
#     Customer Id                                               Name  Gender  \
# 0             1                            Braund, Mr. Owen Harris    Male
# 1             2  Cumings, Mrs. John Bradley Florence Briggs Tha...  Female
# 2             3                             Heikkinen, Miss. Laina  Female
# 3             4       Futrelle, Mrs. Jacques Heath Lily May Peel..  Female
# 4             5                           Allen, Mr. William Henry    Male
# 5             6                                   Moran, Mr. James    Male
# 6             7                            McCarthy, Mr. Timothy J    Male
# 7             8                     Palsson, Master. Gosta Leonard    Male
# 8             9    Johnson, Mrs. Oscar W Elisabeth Vilhelmina Berg  Female
# 9            10                  Nasser, Mrs. Nicholas Adele Achem  Female
# 10           11                    Sandstrom, Miss. Marguerite Rut  Female
# ...

# %%
df
# Out:
#     Customer Id                                               Name  Gender  \
# 0             1                            Braund, Mr. Owen Harris    Male
# 1             2  Cumings, Mrs. John Bradley Florence Briggs Tha...  Female
# 2             3                             Heikkinen, Miss. Laina  Female
# 3             4       Futrelle, Mrs. Jacques Heath Lily May Peel..  Female
# 4             5                           Allen, Mr. William Henry    Male
# 5             6                                   Moran, Mr. James    Male
# 6             7                            McCarthy, Mr. Timothy J    Male
# 7             8                     Palsson, Master. Gosta Leonard    Male
# 8             9    Johnson, Mrs. Oscar W Elisabeth Vilhelmina Berg  Female
# 9            10                  Nasser, Mrs. Nicholas Adele Achem  Female
# 10           11                    Sandstrom, Miss. Marguerite Rut  Female
# ...

# %%
df=df.reset_index(drop=True)
df
# Out:
#     Customer Id                                               Name  Gender  \
# 0             1                            Braund, Mr. Owen Harris    Male
# 1             2  Cumings, Mrs. John Bradley Florence Briggs Tha...  Female
# 2             3                             Heikkinen, Miss. Laina  Female
# 3             4       Futrelle, Mrs. Jacques Heath Lily May Peel..  Female
# 4             5                           Allen, Mr. William Henry    Male
# 5             6                                   Moran, Mr. James    Male
# 6             7                            McCarthy, Mr. Timothy J    Male
# 7             8                     Palsson, Master. Gosta Leonard    Male
# 8             9    Johnson, Mrs. Oscar W Elisabeth Vilhelmina Berg  Female
# 9            10                  Nasser, Mrs. Nicholas Adele Achem  Female
# 10           11                    Sandstrom, Miss. Marguerite Rut  Female
# ...

# %%
df=df.drop([24,25,26,27,28])

# %%
df
# Out:
#     Customer Id                                               Name  Gender  \
# 0             1                            Braund, Mr. Owen Harris    Male
# 1             2  Cumings, Mrs. John Bradley Florence Briggs Tha...  Female
# 2             3                             Heikkinen, Miss. Laina  Female
# 3             4       Futrelle, Mrs. Jacques Heath Lily May Peel..  Female
# 4             5                           Allen, Mr. William Henry    Male
# 5             6                                   Moran, Mr. James    Male
# 6             7                            McCarthy, Mr. Timothy J    Male
# 7             8                     Palsson, Master. Gosta Leonard    Male
# 8             9    Johnson, Mrs. Oscar W Elisabeth Vilhelmina Berg  Female
# 9            10                  Nasser, Mrs. Nicholas Adele Achem  Female
# 10           11                    Sandstrom, Miss. Marguerite Rut  Female
# ...

# %%
#lets just check the shape of the data if there is any duplacy
df2
# Out:
# (32, 11)

# %%
#now it is time for cleaned one 
df2.head()
# Out:
#    Customer Id                                               Name  Gender  \
# 0            1                         ###Braund, Mr. Owen Harris    male
# 1            2  %%Cumings, Mrs. John Bradley (Florence Briggs ...  female
# 2            3                            <Heikkinen, Miss. Laina  female
# 3            4     Futrelle, Mrs. Jacques Heath (Lily May Peel)..   women
# 4            5                           Allen, Mr. William Henry     man
#
#     Age                                Address  Phone_Number Do_Not_Contact  \
# 0  22.0                  123 Shire Lane, Shire  123-545-5421             No
# 1  38.0                    93 West Main Street  123/643/9775            Yes
# 2  26.0                     298 Drugs Driveway    7066950392            NaN
# 3  35.0  980 Paper Avenue, Pennsylvania, 18503  123-543-2345              Y
# 4  35.0                       123 Dragons Road  876|678|3469             No
#
#    SibSp  embark_town alive  alone
# ...

# %%
#you can see that the shape of the data is different which means the data is cleaned now can be used for futher analysis
#thankuuu for watching the video

# %%
for i in df2.index:
    if df2.loc[i,'Do_Not_Contact']=='Yes':
        df2.drop(i,inplace=True)

# %%
df2.shape
# Out:
# (28, 11)

# %%
df2['Do_Not_Contact']=df2['Do_Not_Contact'].replace({'Y':'Yes','N':'No'})

# %%
df2['Phone_Number']=df2['Phone_Number'].fillna('No',inplace=True)
# Out:
# C:\Users\RASIK AHMAD DAR\AppData\Local\Temp\ipykernel_1836\383337232.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['Phone_Number']=df2['Phone_Number'].fillna('No',inplace=True)

# %%
df2['Phone_Number']
# Out:
# 0     None
# 2     None
# 3     None
# 4     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 19    None
# 20    None
# 21    None
# 23    None
# 24    None
# 25    None
# 26    None
# 27    None
# 28    None
# 29    None
# 30    None
# 31    None
# Name: Phone_Number, dtype: object

# %%
df2['Phone_Number']=df2['Phone_Number'].astype(str).replace('[^a-zA-Z0-9]','',regex=True)

# %%
df2
# Out:
#     Customer Id                                               Name  Gender  \
# 0             1                         ###Braund, Mr. Owen Harris    male
# 2             3                            <Heikkinen, Miss. Laina  female
# 3             4     Futrelle, Mrs. Jacques Heath (Lily May Peel)..   women
# 4             5                           Allen, Mr. William Henry     man
# 6             7                            McCarthy, Mr. Timothy J    male
# 7             8                     Palsson, Master. Gosta Leonard    male
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
# 11           12                           Bonnell, Miss. Elizabeth  female
# 12           13                     Saundercock, Mr. William Henry    male
# ...

# %%
df2.drop_duplicates(inplace=True)

# %%
df2.shape
# Out:
# (32, 11)
