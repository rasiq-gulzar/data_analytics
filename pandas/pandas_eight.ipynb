# %%
import pandas as pd

# %%
df=pd.read_excel('C:\\Users\\RASIK AHMAD DAR\\Downloads\\Customer Call List.xlsx')

# %%
df.head()
# Out:
#    CustomerID First_Name  Last_Name  Phone_Number  \
# 0        1001      Frodo    Baggins  123-545-5421
# 1        1002       Abed     #Nadir  123/643/9775
# 2        1003     Walter     /White    7066950392
# 3        1004     Dwight  Schrute__  123-543-2345
# 4        1005        Jon      Snow/  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
df.shape
# Out:
# (28, 8)

# %%
df.drop_duplicates('CustomerID',inplace=True)

# %%
df['Last_Name']=df['Last_Name'].str.replace('[^a-zA-Z]', '', regex=True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
df['Phone_Number'].astype(str).str.replace('[^a-zA-Z0-9]','', regex=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[268], line 1
# ----> 1 df['Phone_Number'].astype(str).str.replace('[^a-zA-Z0-9]','', regex=True)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df['Phone_Number'].astype(str).str.replace('[^a-zA-Z0-9]','', regex=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[205], line 1
# ----> 1 df['Phone_Number']=df['Phone_Number'].astype(str).str.replace('[^a-zA-Z0-9]','', regex=True)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White   7066950392
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          nan
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN           Na
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee          nan
# 11        1012      Harry      Potter   7066950392
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# ...

# %%
df['Do_Not_Contact'].replace({'Y':'Yes','N':'No'},inplace=True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White   7066950392
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          nan
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN           Na
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee          nan
# 11        1012      Harry      Potter   7066950392
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# ...

# %%
df['Do_Not_Contact'].fillna('No',inplace=True)

# %%
df.drop(columns='Not_Useful_Column',inplace=True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White   7066950392
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          nan
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN           Na
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee          nan
# 11        1012      Harry      Potter   7066950392
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# ...

# %%
for i in df.index:
    if df.loc[i,'Do_Not_Contact']=='Yes':
        df.drop(i,inplace=True)

# %%
df['Paying Customer'].replace({'Y':'Yes','N':'No'},inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.fillna('',inplace=True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1003     Walter       White   7066950392
# 2         1005        Jon        Snow   8766783469
# 3         1007       Jeff      Winger          nan
# 4         1008   Sherlock      Holmes   8766783469
# 5         1009    Gandalf                       Na
# 6         1010      Peter      Parker   1235455421
# 7         1011    Samwise      Gamgee          nan
# 8         1012      Harry      Potter   7066950392
# 9         1013        Don      Draper   1235432345
# 10        1014     Leslie       Knope   8766783469
# 11        1015       Toby  Flenderson   3047622467
# 12        1016        Ron     Weasley   1235455421
# 13        1017   Michael        Scott   1236439775
# 14        1018      Clark        Kent   7066950392
# 15        1020     Anakin   Skywalker   8766783469
#
#                            Address Paying Customer Do_Not_Contact
# ...

# %%
df.to_excel('C:\\Users\\RASIK AHMAD DAR\\Downloads\\Customer Call List2.xlsx')

# %%
#now we can only have the street in the address column
df[['Address','pin']]=df['Address'].str.split(',',expand =True, n=2)

# %%
df.drop(columns='pin',inplace=True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number               Address  \
# 0         1001      Frodo     Baggins   1235455421        123 Shire Lane
# 1         1003     Walter       White   7066950392    298 Drugs Driveway
# 2         1005        Jon        Snow   8766783469      123 Dragons Road
# 3         1007       Jeff      Winger          nan     1209 South Street
# 4         1008   Sherlock      Holmes   8766783469         98 Clue Drive
# 5         1009    Gandalf                       Na      123 Middle Earth
# 6         1010      Peter      Parker   1235455421      25th Main Street
# 7         1011    Samwise      Gamgee          nan        612 Shire Lane
# 8         1012      Harry      Potter   7066950392  2394 Hogwarts Avenue
# 9         1013        Don      Draper   1235432345      2039 Main Street
# 10        1014     Leslie       Knope   8766783469      343 City Parkway
# 11        1015       Toby  Flenderson   3047622467         214 HR Avenue
# ...

# %%
df['Phone_Number']=df['Phone_Number'].str.replace('Na','nan')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number               Address  \
# 0         1001      Frodo     Baggins   1235455421        123 Shire Lane
# 1         1003     Walter       White   7066950392    298 Drugs Driveway
# 2         1005        Jon        Snow   8766783469      123 Dragons Road
# 3         1007       Jeff      Winger          nan     1209 South Street
# 4         1008   Sherlock      Holmes   8766783469         98 Clue Drive
# 5         1009    Gandalf                      nan      123 Middle Earth
# 6         1010      Peter      Parker   1235455421      25th Main Street
# 7         1011    Samwise      Gamgee          nan        612 Shire Lane
# 8         1012      Harry      Potter   7066950392  2394 Hogwarts Avenue
# 9         1013        Don      Draper   1235432345      2039 Main Street
# 10        1014     Leslie       Knope   8766783469      343 City Parkway
# 11        1015       Toby  Flenderson   3047622467         214 HR Avenue
# ...

# %%
for i in df.index:
    if df.loc[i,'Phone_Number']=='nan':
        df.drop(i,inplace=True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number               Address  \
# 0         1001      Frodo     Baggins   1235455421        123 Shire Lane
# 1         1003     Walter       White   7066950392    298 Drugs Driveway
# 2         1005        Jon        Snow   8766783469      123 Dragons Road
# 4         1008   Sherlock      Holmes   8766783469         98 Clue Drive
# 6         1010      Peter      Parker   1235455421      25th Main Street
# 8         1012      Harry      Potter   7066950392  2394 Hogwarts Avenue
# 9         1013        Don      Draper   1235432345      2039 Main Street
# 10        1014     Leslie       Knope   8766783469      343 City Parkway
# 11        1015       Toby  Flenderson   3047622467         214 HR Avenue
# 12        1016        Ron     Weasley   1235455421  2395 Hogwarts Avenue
# 13        1017   Michael        Scott   1236439775      121 Paper Avenue
# 14        1018      Clark        Kent   7066950392       3498 Super Lane
# ...

# %%
print(type(df['Phone_Number']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
phone_numbers=df['Phone_Number']
