# %%
import pandas as pd
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\RASIK AHMAD DAR\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\RASIK AHMAD DAR\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\RASIK AHMAD DAR\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
# ...

# %%
df=pd.read_json('C:\\Users\\RASIK AHMAD DAR\\Desktop\\python basics\\DE\\pandas\\new.json')
df2=pd.DataFrame(df)
df2.insert(8,'marks',df2['age'])
df2.drop(['marks'],axis=1,inplace=True)
df2.insert(8,'notice_period',df2['age']/15)
df2.head(40)
# Out:
#     id             name  age            city          occupation  salary  \
# 0    1      Alice Smith   30        New York            Engineer   90000
# 1    2      Bob Johnson   25     Los Angeles            Designer   75000
# 2    3    Charlie Brown   40         Chicago             Manager  110000
# 3    4      Diana Davis   28         Houston             Analyst   80000
# 4    5     Ethan Miller   35         Phoenix           Developer   95000
# 5    6     Fiona Wilson   23    Philadelphia              Intern   50000
# 6    7     George White   45     San Antonio            Director  130000
# 7    8    Hannah Taylor   31       San Diego              Tester   85000
# 8    9        Ian Moore   29          Dallas          Consultant   92000
# 9   10      Julia Clark   33        San Jose           Architect  100000
# 10  11        Kevin Lee   27          Austin            Marketer   78000
# 11  12       Laura King   42    Jacksonville          HR Manager  115000
# ...

# %%
#i have to find the salary greater than 100000 withe names of the persons withe the salaries
# df3=df2[df2['salary']>100000]
# print(df3[['id','name','city','occupation','salary','is_active','join_date','notice_period']])
df4=df2[df2['is_active']==True]
df4.head(40)
total_salary=df2['salary'].sum()
print(total_salary)
# Out:
# 92314.60674157304

# %%
age=df2[df2['age']>30]
print(age[['name','age']])
# Out:
#                   name  age
# 2        Charlie Brown   40
# 4         Ethan Miller   35
# 6         George White   45
# 7        Hannah Taylor   31
# 9          Julia Clark   33
# 11          Laura King   42
# 12         Martin Hall   38
# 14        Oliver Baker   34
# 16          Quinn Hill   39
# 17           Rose King   32
# 18        Samuel Young   41
# 20       Victor Wright   37
# 22       Xavier Carter   43
# 23           Yara Wood   31
# 24           Zane Reed   36
# 26       Benjamin Cole   40
# 28        Daniel Evans   33
# 30      Franklin Green   38
# 31          Grace Hall   32
# 33      Isabella Jones   41
# 35     Katherine Lewis   34
# 36          Liam Moore   45
# 39        Olivia Perry   36
# 41      Penelope Reyes   40
# 42       Quentin Scott   31
# 44    Samuel Underwood   35
# 46      Ulysses Wagner   39
# 47         Violet Wood   33
# 49         Xena Zamora   44
# 50        Ava Martinez   32
# 52        Clara Nelson   38
# 54       Ella Peterson   36
# ...

# %%
age=df2[df2['age']>30]
print(age[['name','age']])
# Out:
#                   name  age
# 2        Charlie Brown   40
# 4         Ethan Miller   35
# 6         George White   45
# 7        Hannah Taylor   31
# 9          Julia Clark   33
# 11          Laura King   42
# 12         Martin Hall   38
# 14        Oliver Baker   34
# 16          Quinn Hill   39
# 17           Rose King   32
# 18        Samuel Young   41
# 20       Victor Wright   37
# 22       Xavier Carter   43
# 23           Yara Wood   31
# 24           Zane Reed   36
# 26       Benjamin Cole   40
# 28        Daniel Evans   33
# 30      Franklin Green   38
# 31          Grace Hall   32
# 33      Isabella Jones   41
# 35     Katherine Lewis   34
# 36          Liam Moore   45
# 39        Olivia Perry   36
# 41      Penelope Reyes   40
# 42       Quentin Scott   31
# 44    Samuel Underwood   35
# 46      Ulysses Wagner   39
# 47         Violet Wood   33
# 49         Xena Zamora   44
# 50        Ava Martinez   32
# 52        Clara Nelson   38
# 54       Ella Peterson   36
# ...

# %%
eng=df2[df2['occupation']=='Engineer']
print(eng[['name','id','salary']])
# Out:
#           name  id  salary
# 0  Alice Smith   1   90000
