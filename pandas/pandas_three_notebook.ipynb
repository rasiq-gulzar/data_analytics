# %%
import pandas as pd
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\RASIK AHMAD DAR\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\RASIK AHMAD DAR\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\RASIK AHMAD DAR\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
# ...

# %%
data=pd.read_csv('C:\\Users\\RASIK AHMAD DAR\\Downloads\\tested.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# data.info()
#now i have to bypass the dataset set to print it fully withe details of all columns and rows
pd.set_option('display.max.rows',None)
data
pclass=data['Pclass']
pclass.to_csv('C:\\Users\\RASIK AHMAD DAR\\Downloads\\pclass.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
missingAge=data[data['Age'].isnull()]
missingAge
# Out:
#      PassengerId  Survived  Pclass  \
# 10           902         0       3
# 22           914         1       1
# 29           921         0       3
# 33           925         1       3
# 36           928         1       3
# 39           931         0       3
# 41           933         0       1
# 47           939         0       3
# 54           946         0       2
# 58           950         0       3
# 65           957         1       2
# 76           968         0       3
# 83           975         0       3
# 84           976         0       2
# 85           977         0       3
# 88           980         1       3
# 91           983         0       3
# 93           985         0       3
# 102          994         0       3
# 107          999         0       3
# 108         1000         0       3
# 111         1003         1       3
# 116         1008         0       3
# 121         1013         0       3
# 124         1016         0       3
# ...

# %%
data_three=data['Age'].notnull()
data_three.shape
# Out:
# (418,)

# %%
cabinNotAlot=data[data['Cabin'].isnull()]
cabinNotAlot
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# 6            898         1       3
# 7            899         0       2
# 8            900         1       3
# 9            901         0       3
# 10           902         0       3
# 11           903         0       1
# 13           905         0       2
# 15           907         1       2
# 16           908         0       2
# 17           909         0       3
# 18           910         1       3
# 19           911         1       3
# 20           912         0       1
# 21           913         0       3
# 22           914         1       1
# 23           915         0       1
# 25           917         0       3
# 27           919         0       3
# 29           921         0       3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
survived=data[data['Survived']==1]
survived
survived.shape
# Out:
# (152, 12)

# %%
fare=data[data['Fare'].isnull()]
fare
# Out:
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 152         1044         0       3  Storey, Mr. Thomas  male  60.5      0
#
#      Parch Ticket  Fare Cabin Embarked
# 152      0   3701   NaN   NaN        S

# %%
male=data[data['Sex']=='male']
male.shape
# Out:
# (266, 12)

# %%
female=data[data['Sex']=='female']
print(female[['Name','Age','Embarked']])
# Out:
#                                                   Name    Age Embarked
# 1                     Wilkes, Mrs. James (Ellen Needs)  47.00        S
# 4         Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.00        S
# 6                                 Connolly, Miss. Kate  30.00        Q
# 8            Abrahim, Mrs. Joseph (Sophie Halaut Easu)  18.00        C
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  23.00        S
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  47.00        S
# 15       del Carlo, Mrs. Sebastiano (Argenia Genovesi)  24.00        C
# 18                        Ilmakangas, Miss. Ida Livija  27.00        S
# 19               Assaf Khalil, Mrs. Mariana (Miriam")"  45.00        C
# 22                Flegenheim, Mrs. Alfred (Antoinette)    NaN        S
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  48.00        C
# 26                        Ostby, Miss. Helene Ragnhild  22.00        C
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df=pd.read_csv('C:\\Users\\RASIK AHMAD DAR\\Downloads\\accident.csv')
df.head()
# Out:
#    Age  Gender  Speed_of_Impact Helmet_Used Seatbelt_Used  Survived
# 0   56  Female             27.0          No            No         1
# 1   69  Female             46.0          No           Yes         1
# 2   46    Male             46.0         Yes           Yes         0
# 3   32    Male            117.0          No           Yes         0
# 4   60  Female             40.0         Yes           Yes         0

# %%
address=data.head(199)
address.shape
address
df.info()
df['Accident Place']=address['Name']
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              200 non-null    int64
#  1   Gender           199 non-null    object
#  2   Speed_of_Impact  197 non-null    float64
#  3   Helmet_Used      200 non-null    object
#  4   Seatbelt_Used    200 non-null    object
#  5   Survived         200 non-null    int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 9.5+ KB
#      Age  Gender  Speed_of_Impact Helmet_Used Seatbelt_Used  Survived  \
# 0     56  Female             27.0          No            No         1
# 1     69  Female             46.0          No           Yes         1
# 2     46    Male             46.0         Yes           Yes         0
# 3     32    Male            117.0          No           Yes         0
# 4     60  Female             40.0         Yes           Yes         0
# ...

# %%
df.shape
# Out:
# (200, 7)

# %%
female=df[df['Gender']=='Female']
female
# Out:
#      Age  Gender  Speed_of_Impact Helmet_Used Seatbelt_Used  Survived  \
# 0     56  Female             27.0          No            No         1
# 1     69  Female             46.0          No           Yes         1
# 4     60  Female             40.0         Yes           Yes         0
# 8     36  Female             83.0         Yes            No         1
# 9     40  Female            116.0         Yes            No         1
# 10    28  Female             88.0          No           Yes         1
# 13    53  Female             38.0         Yes           Yes         1
# 14    57  Female             23.0          No           Yes         0
# 15    41  Female              NaN          No            No         0
# 16    20  Female             83.0         Yes           Yes         0
# 18    19  Female             36.0         Yes           Yes         1
# 20    61  Female            111.0          No            No         0
# ...

# %%
female.shape
# Out:
# (110, 7)

# %%
survived=female[df['Survived']==1]
survived
# Out:
# C:\Users\RASIK AHMAD DAR\AppData\Local\Temp\ipykernel_12536\160558034.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survived=female[df['Survived']==1]
#      Age  Gender  Speed_of_Impact Helmet_Used Seatbelt_Used  Survived  \
# 0     56  Female             27.0          No            No         1
# 1     69  Female             46.0          No           Yes         1
# 8     36  Female             83.0         Yes            No         1
# 9     40  Female            116.0         Yes            No         1
# 10    28  Female             88.0          No           Yes         1
# 13    53  Female             38.0         Yes           Yes         1
# 18    19  Female             36.0         Yes           Yes         1
# 23    19  Female             65.0          No            No         1
# 25    50  Female            118.0         Yes           Yes         1
# 37    68  Female             51.0          No            No         1
# ...

# %%
survived.shape
# Out:
# (50, 7)

# %%
male=df[df['Gender']=='Male']
male
# Out:
#      Age Gender  Speed_of_Impact Helmet_Used Seatbelt_Used  Survived  \
# 2     46   Male             46.0         Yes           Yes         0
# 3     32   Male            117.0          No           Yes         0
# 5     25   Male             49.0         Yes           Yes         1
# 6     38   Male            116.0         Yes           Yes         1
# 7     56   Male             47.0         Yes           Yes         1
# 11    28   Male             80.0         Yes           Yes         1
# 12    41   Male             67.0         Yes            No         1
# 17    39   Male             68.0          No            No         0
# 19    41   Male              NaN         Yes            No         1
# 21    47   Male             49.0         Yes            No         1
# 26    29   Male             56.0          No           Yes         1
# 28    61   Male            112.0         Yes            No         1
# 29    42   Male              NaN         Yes            No         0
# ...

# %%
male.shape
# Out:
# (89, 7)

# %%
survived_male=male[male['Survived']==1]
survived_male
# Out:
#      Age Gender  Speed_of_Impact Helmet_Used Seatbelt_Used  Survived  \
# 5     25   Male             49.0         Yes           Yes         1
# 6     38   Male            116.0         Yes           Yes         1
# 7     56   Male             47.0         Yes           Yes         1
# 11    28   Male             80.0         Yes           Yes         1
# 12    41   Male             67.0         Yes            No         1
# 19    41   Male              NaN         Yes            No         1
# 21    47   Male             49.0         Yes            No         1
# 26    29   Male             56.0          No           Yes         1
# 28    61   Male            112.0         Yes            No         1
# 33    45   Male             79.0          No           Yes         1
# 34    33   Male            116.0          No            No         1
# 35    32   Male             82.0          No           Yes         1
# 40    20   Male             86.0         Yes           Yes         1
# ...

# %%
survived_male.shape
# Out:
# (51, 7)

# %%
seat_belt_one=male[male['Seatbelt_Used']=='Yes']
seat_belt_one
seat_belt_one.shape
# Out:
# (46, 7)

# %%
helmet_on=male[male['Helmet_Used']=='Yes']
helmet_on
helmet_on.shape
# Out:
# (51, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              200 non-null    int64
#  1   Gender           199 non-null    object
#  2   Speed_of_Impact  197 non-null    float64
#  3   Helmet_Used      200 non-null    object
#  4   Seatbelt_Used    200 non-null    object
#  5   Survived         200 non-null    int64
#  6   Accident Place   199 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 11.1+ KB

# %%
survived=df[df['Survived']==1]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              200 non-null    int64
#  1   Gender           199 non-null    object
#  2   Speed_of_Impact  197 non-null    float64
#  3   Helmet_Used      200 non-null    object
#  4   Seatbelt_Used    200 non-null    object
#  5   Survived         200 non-null    int64
#  6   Accident Place   199 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 11.1+ KB

# %%
not_mentioned=df[df['Speed_of_Impact'].isnull()]
not_mentioned
# Out:
#     Age  Gender  Speed_of_Impact Helmet_Used Seatbelt_Used  Survived  \
# 15   41  Female              NaN          No            No         0
# 19   41    Male              NaN         Yes            No         1
# 29   42    Male              NaN         Yes            No         0
#
#                                    Accident Place
# 15  del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 19          Assaf Khalil, Mrs. Mariana (Miriam")"
# 29                              Samaan, Mr. Elias

# %%
male_speedOfImpact=df[df['Speed_of_Impact']>100]
male_speedOfImpact
male_speedOfImpact.shape
# Out:
# (47, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              200 non-null    int64
#  1   Gender           199 non-null    object
#  2   Speed_of_Impact  197 non-null    float64
#  3   Helmet_Used      200 non-null    object
#  4   Seatbelt_Used    200 non-null    object
#  5   Survived         200 non-null    int64
#  6   Accident Place   199 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 11.1+ KB
