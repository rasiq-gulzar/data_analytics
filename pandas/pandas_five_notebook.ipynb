# %%
import pandas as pd

# %%
data=pd.read_csv('C:\\Users\\RASIK AHMAD DAR\\Downloads\\tested.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# 6            898         1       3
# 7            899         0       2
# 8            900         1       3
# 9            901         0       3
# 10           902         0       3
# 11           903         0       1
# 12           904         1       1
# 13           905         0       2
# 14           906         1       1
# 15           907         1       2
# 16           908         0       2
# 17           909         0       3
# 18           910         1       3
# 19           911         1       3
# 20           912         0       1
# 21           913         0       3
# 22           914         1       1
# 23           915         0       1
# 24           916         1       1
# ...

# %%
data.shape
# Out:
# (418, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.sort_values('Age')
# Out:
#      PassengerId  Survived  Pclass  \
# 354         1246         1       3
# 201         1093         0       3
# 281         1173         0       3
# 307         1199         0       3
# 250         1142         1       2
# 117         1009         1       3
# 296         1188         1       2
# 263         1155         1       3
# 284         1176         1       3
# 89           981         0       2
# 409         1301         1       3
# 379         1271         0       3
# 389         1281         0       3
# 80           972         0       3
# 196         1088         0       1
# 161         1053         0       3
# 203         1095         1       2
# 194         1086         0       2
# 283         1175         1       3
# 21           913         0       3
# 140         1032         1       3
# 55           947         0       3
# 192         1084         0       3
# 120         1012         1       2
# 326         1218         1       2
# ...

# %%
data.sort_values('Embarked',inplace=True)
data2=data.reset_index()
data2.drop(columns='index',inplace=True)
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0           1100         1       1
# 1           1069         0       1
# 2           1071         1       1
# 3           1073         0       1
# 4           1076         1       1
# 5           1088         0       1
# 6           1094         0       1
# 7           1097         0       1
# 8           1110         1       1
# 9           1112         1       2
# 10          1116         1       1
# 11          1117         1       3
# 12          1126         0       1
# 13          1128         0       1
# 14          1129         0       3
# 15          1131         1       1
# 16          1065         0       3
# 17          1063         0       3
# 18          1060         1       1
# 19          1058         0       1
# 20           986         0       1
# 21           992         1       1
# 22           996         1       3
# 23          1002         0       2
# 24          1004         1       1
# ...

# %%
#data extraction colmun wise for name and the Embarked
a=data[['Name','Embarked']]
a
# Out:
#                                                   Name Embarked
# 208                      Rosenbaum, Miss. Edith Louise        C
# 177                    Stengel, Mr. Charles Emil Henry        C
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...        C
# 181                   Compton, Mr. Alexander Taylor Jr        C
# 184  Douglas, Mrs. Frederick Charles (Mary Helene B...        C
# 196                    Spedden, Master. Robert Douglas        C
# 202                             Astor, Col. John Jacob        C
# 205                          Omont, Mr. Alfred Fernand        C
# 218       Widener, Mrs. George Dunton (Eleanor Elkins)        C
# 220                     Duran y More, Miss. Florentina        C
# 224   Candee, Mrs. Edward (Helen Churchill Hungerford)        C
# 225   Moubarek, Mrs. George (Omine Amenia" Alexander)"        C
# 234                          Cumings, Mr. John Bradley        C
# 236                           Warren, Mr. Frank Manley        C
# ...

# %%
#data extraction row wise for 1st 10 rows using iloc it slices the data bases on the index like list slicing
c=a.iloc[0:102]
c.reset_index(inplace=True)
c
# Out:
#      index                                               Name Embarked
# 0      208                      Rosenbaum, Miss. Edith Louise        C
# 1      177                    Stengel, Mr. Charles Emil Henry        C
# 2      179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...        C
# 3      181                   Compton, Mr. Alexander Taylor Jr        C
# 4      184  Douglas, Mrs. Frederick Charles (Mary Helene B...        C
# 5      196                    Spedden, Master. Robert Douglas        C
# 6      202                             Astor, Col. John Jacob        C
# 7      205                          Omont, Mr. Alfred Fernand        C
# 8      218       Widener, Mrs. George Dunton (Eleanor Elkins)        C
# 9      220                     Duran y More, Miss. Florentina        C
# 10     224   Candee, Mrs. Edward (Helen Churchill Hungerford)        C
# 11     225   Moubarek, Mrs. George (Omine Amenia" Alexander)"        C
# ...

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
survived=data[data['Survived']==1]
print(survived['Name'])
# Out:
# 208                        Rosenbaum, Miss. Edith Louise
# 179    Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 184    Douglas, Mrs. Frederick Charles (Mary Helene B...
# 218         Widener, Mrs. George Dunton (Eleanor Elkins)
# 220                       Duran y More, Miss. Florentina
# 224     Candee, Mrs. Edward (Helen Churchill Hungerford)
# 225     Moubarek, Mrs. George (Omine Amenia" Alexander)"
# 239          Douglas, Mrs. Walter Donald (Mahala Dutton)
# 168    Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 100    Stengel, Mrs. Charles Emil Henry (Annie May Mo...
# 104            Thomas, Mrs. Alexander (Thamine Thelma")"
# 112                             Evans, Miss. Edith Corse
# 240            Lindstrom, Mrs. Carl Johan (Sigrid Posse)
# 150                Earnshaw, Mrs. Boulton (Olive Potter)
# 122                      Schabert, Mrs. Paul (Emma Mock)
# 249            Khalil, Mrs. Betros (Zahie Maria" Elias)"
# ...

# %%
not_survived=data[data['Survived']==0]
print(not_survived['Name'])
# Out:
# 177                      Stengel, Mr. Charles Emil Henry
# 181                     Compton, Mr. Alexander Taylor Jr
# 196                      Spedden, Master. Robert Douglas
# 202                               Astor, Col. John Jacob
# 205                            Omont, Mr. Alfred Fernand
# 234                            Cumings, Mr. John Bradley
# 236                             Warren, Mr. Frank Manley
# 237                                  Baccos, Mr. Raffull
# 173                                     Torfa, Mr. Assad
# 171                                  Zakarian, Mr. Ortin
# 166                                   Brandeis, Mr. Emil
# 94                                   Birnbaum, Mr. Jakob
# 110                             Stanton, Mr. Samuel Ward
# 115                          Chronopoulos, Mr. Demetrios
# 116                                     Thomas, Mr. John
# 118                                 Beattie, Mr. Thomson
# ...

# %%
survived_data=data.sort_values('Survived')
survived_data
pd.set_option('display.max_rows',None)
survived_data.reset_index(inplace=True)
survived_data.drop(columns='index',inplace=True)

# %%
s=survived_data.iloc[0:266]
print(s['Name'])
# Out:
# 0                        Peltomaki, Mr. Nikolai Johannes
# 1                            Franklin, Mr. Thomas Parham
# 2                                  Goldsmith, Mr. Nathan
# 3                                 Vendel, Mr. Olof Edvin
# 4                                          Hee, Mr. Ling
# 5                            Sweet, Mr. George Frederick
# 6                     Hocking, Mr. Samuel James Metcalfe
# 7                              Everett, Mr. Thomas James
# 8                                    Lockyer, Mr. Edward
# 9                                     Pedersen, Mr. Olaf
# 10                           Sage, Master. William Henry
# 11                                  Howard, Mr. Benjamin
# 12                                     Strilic, Mr. Ivan
# 13                          Cotterill, Mr. Henry Harry""
# 14                          Caldwell, Mr. Albert Francis
# 15                                Harbeck, Mr. William H
# ...

# %%
nots=survived_data.iloc[267:418]
print(nots['Name'])
# Out:
# 267    Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 268    Stengel, Mrs. Charles Emil Henry (Annie May Mo...
# 269            Thomas, Mrs. Alexander (Thamine Thelma")"
# 270                             Evans, Miss. Edith Corse
# 271            Lindstrom, Mrs. Carl Johan (Sigrid Posse)
# 272          Douglas, Mrs. Walter Donald (Mahala Dutton)
# 273      Chapman, Mrs. John Henry (Sara Elizabeth Lawry)
# 274                                Hiltunen, Miss. Marta
# 275                Corbett, Mrs. Walter H (Irene Colvin)
# 276     Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)
# 277                  Fortune, Mrs. Mark (Mary McDougald)
# 278                             Willard, Miss. Constance
# 279                        Rosenbaum, Miss. Edith Louise
# 280     Becker, Mrs. Allen Oliver (Nellie E Baumgardner)
# 281    Lindell, Mrs. Edvard Bengtsson (Elin Gerda Per...
# 282         Ware, Mrs. John James (Florence Louise Long)
# ...

# %%
survived_data2={
                }
    
survived_data2=pd.DataFrame(survived_data2)
survived_data2.insert(0,'Survived',s['Survived'])
survived_data2.insert(1,'Name',s['Name'])
survived_data2.shape
# Out:
# (266, 2)

# %%
survived_data3={
                }
    
survived_data3=pd.DataFrame(survived_data3)
survived_data3.insert(0,'Survived Name',s['Name'])
survived_data3.insert(1,'Not Survived Name',nots['Name'])
survived_data3.reset_index(inplace=True)
survived_data3.drop(columns='index',inplace=True)
nots.reset_index(inplace=True)

# %%
survived_data3['Not Survived Name'].fillna('Not data',inplace=True)
survived_data3.to_csv('ttt.csv')

# %%
cabin=data.sort_values('Cabin')
cabin.reset_index(inplace=True)
cabin.drop(columns='index',inplace=True)

# %%
theif=cabin.iloc[71:72]
print(theif['Name'])
# Out:
# 71    Frauenthal, Mr. Isaac Gerald
# Name: Name, dtype: object

# %%
df=pd.read_excel('survived_data.xlsx')
df
# Out:
#      Unnamed: 0                                      Survived Name  \
# 0             0                    Peltomaki, Mr. Nikolai Johannes
# 1             1                        Franklin, Mr. Thomas Parham
# 2             2                              Goldsmith, Mr. Nathan
# 3             3                             Vendel, Mr. Olof Edvin
# 4             4                                      Hee, Mr. Ling
# 5             5                        Sweet, Mr. George Frederick
# 6             6                 Hocking, Mr. Samuel James Metcalfe
# 7             7                          Everett, Mr. Thomas James
# 8             8                                Lockyer, Mr. Edward
# 9             9                                 Pedersen, Mr. Olaf
# 10           10                        Sage, Master. William Henry
# 11           11                               Howard, Mr. Benjamin
# 12           12                                  Strilic, Mr. Ivan
# ...
