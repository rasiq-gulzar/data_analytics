# %%
import pandas as pd

# %%
df=pd.read_excel('C:\\Users\\RASIK AHMAD DAR\\Downloads\\Customer Call List2.xlsx')

# %%
df
# Out:
#     Unnamed: 0  CustomerID First_Name   Last_Name Phone_Number  \
# 0            0        1001      Frodo     Baggins   1235455421
# 1            1        1003     Walter       White   7066950392
# 2            2        1005        Jon        Snow   8766783469
# 3            3        1007       Jeff      Winger          NaN
# 4            4        1008   Sherlock      Holmes   8766783469
# 5            5        1009    Gandalf         NaN           Na
# 6            6        1010      Peter      Parker   1235455421
# 7            7        1011    Samwise      Gamgee          NaN
# 8            8        1012      Harry      Potter   7066950392
# 9            9        1013        Don      Draper   1235432345
# 10          10        1014     Leslie       Knope   8766783469
# 11          11        1015       Toby  Flenderson   3047622467
# 12          12        1016        Ron     Weasley   1235455421
# 13          13        1017   Michael        Scott   1236439775
# ...

# %%
df['Phone_Number'] = df['Phone_Number'].astype(str).apply(lambda x: x[0:3]+'-'+x[3:6]+'-'+x[6:10])

# %%
df
# Out:
#     Unnamed: 0  CustomerID First_Name   Last_Name  Phone_Number  \
# 0            0        1001      Frodo     Baggins  123-545-5421
# 1            1        1003     Walter       White  706-695-0392
# 2            2        1005        Jon        Snow  876-678-3469
# 3            3        1007       Jeff      Winger         nan--
# 4            4        1008   Sherlock      Holmes  876-678-3469
# 5            5        1009    Gandalf         NaN          Na--
# 6            6        1010      Peter      Parker  123-545-5421
# 7            7        1011    Samwise      Gamgee         nan--
# 8            8        1012      Harry      Potter  706-695-0392
# 9            9        1013        Don      Draper  123-543-2345
# 10          10        1014     Leslie       Knope  876-678-3469
# 11          11        1015       Toby  Flenderson  304-762-2467
# 12          12        1016        Ron     Weasley  123-545-5421
# 13          13        1017   Michael        Scott  123-643-9775
# ...

# %%
df['Phone_Number']=df['Phone_Number'].astype(str).replace('nan--','Phone Number not found')

# %%
df
# Out:
#     Unnamed: 0  CustomerID First_Name   Last_Name            Phone_Number  \
# 0            0        1001      Frodo     Baggins            123-545-5421
# 1            1        1003     Walter       White            706-695-0392
# 2            2        1005        Jon        Snow            876-678-3469
# 3            3        1007       Jeff      Winger  Phone Number not found
# 4            4        1008   Sherlock      Holmes            876-678-3469
# 5            5        1009    Gandalf         NaN                    Na--
# 6            6        1010      Peter      Parker            123-545-5421
# 7            7        1011    Samwise      Gamgee  Phone Number not found
# 8            8        1012      Harry      Potter            706-695-0392
# 9            9        1013        Don      Draper            123-543-2345
# 10          10        1014     Leslie       Knope            876-678-3469
# 11          11        1015       Toby  Flenderson            304-762-2467
# ...

# %%
df['Phone_Number']=df['Phone_Number'].astype(str).replace('Na--','Phone Number not found')

# %%
df
# Out:
#     Unnamed: 0  CustomerID First_Name   Last_Name            Phone_Number  \
# 0            0        1001      Frodo     Baggins            123-545-5421
# 1            1        1003     Walter       White            706-695-0392
# 2            2        1005        Jon        Snow            876-678-3469
# 3            3        1007       Jeff      Winger  Phone Number not found
# 4            4        1008   Sherlock      Holmes            876-678-3469
# 5            5        1009    Gandalf         NaN  Phone Number not found
# 6            6        1010      Peter      Parker            123-545-5421
# 7            7        1011    Samwise      Gamgee  Phone Number not found
# 8            8        1012      Harry      Potter            706-695-0392
# 9            9        1013        Don      Draper            123-543-2345
# 10          10        1014     Leslie       Knope            876-678-3469
# 11          11        1015       Toby  Flenderson            304-762-2467
# ...

# %%
for i in df.index:
    if df.loc[i,'Paying Customer']=='No':
        df.drop(i,inplace=True)

# %%
df
# Out:
#     Unnamed: 0  CustomerID First_Name  Last_Name            Phone_Number  \
# 0            0        1001      Frodo    Baggins            123-545-5421
# 2            2        1005        Jon       Snow            876-678-3469
# 5            5        1009    Gandalf        NaN  Phone Number not found
# 6            6        1010      Peter     Parker            123-545-5421
# 7            7        1011    Samwise     Gamgee  Phone Number not found
# 8            8        1012      Harry     Potter            706-695-0392
# 9            9        1013        Don     Draper            123-543-2345
# 10          10        1014     Leslie      Knope            876-678-3469
# 13          13        1017   Michael       Scott            123-643-9775
# 14          14        1018      Clark       Kent            706-695-0392
# 15          15        1020     Anakin  Skywalker            876-678-3469
#
#                            Address Paying Customer Do_Not_Contact
# ...

# %%
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df
# Out:
#     CustomerID First_Name  Last_Name            Phone_Number  \
# 0         1001      Frodo    Baggins            123-545-5421
# 2         1005        Jon       Snow            876-678-3469
# 5         1009    Gandalf        NaN  Phone Number not found
# 6         1010      Peter     Parker            123-545-5421
# 7         1011    Samwise     Gamgee  Phone Number not found
# 8         1012      Harry     Potter            706-695-0392
# 9         1013        Don     Draper            123-543-2345
# 10        1014     Leslie      Knope            876-678-3469
# 13        1017   Michael       Scott            123-643-9775
# 14        1018      Clark       Kent            706-695-0392
# 15        1020     Anakin  Skywalker            876-678-3469
#
#                            Address Paying Customer Do_Not_Contact
# 0            123 Shire Lane, Shire             Yes             No
# 2                 123 Dragons Road             Yes             No
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#     CustomerID First_Name  Last_Name            Phone_Number  \
# 0         1001      Frodo    Baggins            123-545-5421
# 1         1005        Jon       Snow            876-678-3469
# 2         1009    Gandalf        NaN  Phone Number not found
# 3         1010      Peter     Parker            123-545-5421
# 4         1011    Samwise     Gamgee  Phone Number not found
# 5         1012      Harry     Potter            706-695-0392
# 6         1013        Don     Draper            123-543-2345
# 7         1014     Leslie      Knope            876-678-3469
# 8         1017   Michael       Scott            123-643-9775
# 9         1018      Clark       Kent            706-695-0392
# 10        1020     Anakin  Skywalker            876-678-3469
#
#                            Address Paying Customer Do_Not_Contact
# 0            123 Shire Lane, Shire             Yes             No
# 1                 123 Dragons Road             Yes             No
# ...

# %%
df.to_excel('C:\\Users\\RASIK AHMAD DAR\\Downloads\\Customer Call List3.xlsx',index=False)

# %%
for i in df.index:
    if df.loc[i,'Phone_Number']=='Phone Number not found':
        df.drop(i,inplace=True)

df
# Out:
#     CustomerID First_Name  Last_Name  Phone_Number  \
# 0         1001      Frodo    Baggins  123-545-5421
# 1         1005        Jon       Snow  876-678-3469
# 3         1010      Peter     Parker  123-545-5421
# 5         1012      Harry     Potter  706-695-0392
# 6         1013        Don     Draper  123-543-2345
# 7         1014     Leslie      Knope  876-678-3469
# 8         1017   Michael       Scott  123-643-9775
# 9         1018      Clark       Kent  706-695-0392
# 10        1020     Anakin  Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact
# 0            123 Shire Lane, Shire             Yes             No
# 1                 123 Dragons Road             Yes             No
# 3       25th Main Street, New York             Yes             No
# 5             2394 Hogwarts Avenue             Yes             No
# 6                 2039 Main Street             Yes             No
# ...

# %%
students_data={
    'Student Id':[1,2,3],
    'Name':['Rasiq','Umer','Taseer'],
    'English':[90,80,70],
    'Maths':[80,70,60],
    'Science':[70,60,50]
}

# %%
df2=pd.DataFrame(students_data)

# %%
df2
# Out:
#    Student Id    Name  English  Maths  Science
# 0           1   Rasiq       90     80       70
# 1           2    Umer       80     70       60
# 2           3  Taseer       70     60       50

# %%
df2['Total']=df2['English']+df2['Maths']+df2['Science']

# %%
df2
# Out:
#    Student Id    Name  English  Maths  Science  Total
# 0           1   Rasiq       90     80       70    240
# 1           2    Umer       80     70       60    210
# 2           3  Taseer       70     60       50    180

# %%
df2['Percentage']=df2['Total']/500*100

# %%
df2
# Out:
#    Student Id    Name  English  Maths  Science  Total  Percentage
# 0           1   Rasiq       90     80       70    240        48.0
# 1           2    Umer       80     70       60    210        42.0
# 2           3  Taseer       70     60       50    180        36.0
